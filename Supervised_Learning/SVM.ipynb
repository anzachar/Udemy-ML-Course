# %% [markdown]
# # SVM #

# %% [markdown]
# ### Support Vector Machine ###

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm

# %% [markdown]
# ## Generating Synthetic Dataset ##

# %%
np.random.seed(0)
X=np.r_[np.random.randn(20,2) - [2,2], np.random.randn(20,2) +[2,2]]
y=[0]*20+ [1]*20

# %% [markdown]
# ## Visualizing Dataset ##

# %%
plt.scatter(X[:,0], X[:,1], c=y, cmap=plt.cm.Paired) #visually distinguishable colors
plt.xlabel('X1')
plt.ylabel('X2')
plt.show()

# %% [markdown]
# ## Training the model ##

# %%
clf=svm.SVC(kernel='linear') # different kernels can be used for non-linear problems
clf.fit(X,y)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# ## Visualizing the decision boundary ##

# %%
# Plotting the decision boundary
ax=plt.gca()
xlim=ax.get_xlim()
ylim=ax.get_ylim()

# Creating grid to evaluate model
xx=np.linspace(xlim[0], xlim[1], 30)
yy=np.linspace(ylim[0], ylim[1], 30)
YY,XX=np.meshgrid(yy,xx)
xy=np.vstack([XX.ravel(), YY.ravel()]).T
Z=clf.decision_function(xy).reshape(XX.shape)

# Plot decision boundary
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5, linestyle=['--', '-', '--'])

# Plotting support vectors
ax.scatter(clf.support_vectors_[:,0], clf.support_vectors_[:,1], s=100, linewidth=1, facecolors='none', edgecolors='k')
plt.xlabel('X1')
plt.ylabel('X2')
plt.show
# Out:
# C:\Users\zaxar\AppData\Local\Temp\ipykernel_19388\2002078916.py:14: UserWarning: The following kwargs were not used by contour: 'linestyle'
#   ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5, linestyle=['--', '-', '--'])
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Making Predictions ##

# %%
# generating random new data
np.random.seed(1)
X_test=np.random.randn(10,2)
# making predictions using the classifier
y_pred=clf.predict(X_test)
print("Predictions based on the new data:", y_pred)
# Out:
# Predictions based on the new data: [1 0 0 1 0 0 0 1 0 1]
