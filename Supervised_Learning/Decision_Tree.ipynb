# %% [markdown]
# # Decision Trees #

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, export_graphviz, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import graphviz

# %% [markdown]
# ## Loading iris dataset ##

# %%
iris=load_iris()
X=iris.data
y=iris.target

# %% [markdown]
# ## Splitting the data to training and test set ##

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.3, random_state=1)

# %% [markdown]
# ## Creating Decision Trees Classifier ##
# ### Here, we pick maximum depth of 3 ###

# %%
clf=DecisionTreeClassifier(max_depth=3)

# %% [markdown]
# ## Training the Classifier on the training data set ##

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %% [markdown]
# ## Making predictions on the test data set ##

# %%
y_pred=clf.predict(X_test)

# %% [markdown]
# ## Accuracy Score ##

# %%
accuracy=accuracy_score(y_test, y_pred)

# %%
print("Accuracy of the model predictions: ", accuracy)
# Out:
# Accuracy of the model predictions:  0.9555555555555556

# %% [markdown]
# ## Visualization ##

# %% [markdown]
# I had to do this part differently than what was shown in the course, as I had to install extra things and could not figure it out. This seemes simpler.

# %%
# Visualize the decision tree
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))  # Set the size of the plot
plot_tree(clf, feature_names=iris.feature_names, class_names=iris.target_names, filled=True, rounded=True)
# Save the figure
plt.savefig('decision_tree.png', format='png')  # Save as PNG file
plt.savefig('decision_tree.pdf', format='pdf')  # Save as PDF file
plt.show()
