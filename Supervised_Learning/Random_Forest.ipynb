# %% [markdown]
# # Random Forest #

# %% [markdown]
# Uses multiple decision trees

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Loading dataset ##

# %%
data=load_breast_cancer()

# %% [markdown]
# ## Splitting data to features and classification ##

# %%
X=data.data
y=data.target

# %% [markdown]
# ## Splitting data into training and test set ##

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.3, random_state=42)

# %% [markdown]
# ## Creating Random Forest Classifier ##

# %%
rf_classifier=RandomForestClassifier(n_estimators=100, random_state=42) #n_estimators= number of trees

# %% [markdown]
# ## Training the Classifier using the training dataset ##

# %%
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# ## Making Predictions on the test dataset##

# %%
y_pred=rf_classifier.predict(X_test)

# %% [markdown]
# ## Evaluating Classifier using accuracy score ##

# %%
rf_accuracy=accuracy_score(y_test, y_pred)
print("Random Forest Model accuracy: ", rf_accuracy)
# Out:
# Random Forest Model accuracy:  0.9707602339181286

# %% [markdown]
# ## Getting and Visualizing the feature importances ##

# %%
# getting feature importances
importances=rf_classifier.feature_importances_

# %%
# sorting feature importances in descending order
indices=np.argsort(importances[::-1])
# rearranging features names so they match the sorted feature importances
feature_names=data.feature_names[indices]

# %%
# Creating bar plot of feature importances
plt.figure(figsize=(10, 6))
plt.title("Feauture Importances")
plt.bar(range(X.shape[1]), importances[indices])
plt.xticks(range(X.shape[1]), feature_names, rotation=90)
plt.show()
